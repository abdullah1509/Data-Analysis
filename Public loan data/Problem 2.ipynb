# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1= pd.read_csv('public_150k_plus_210630_2.csv')
data1.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# ...

# %%
data1.shape
# Out:
# (970076, 53)

# %%
data2= pd.read_csv('public_up_to_150k_1_210630.csv')
data2.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  5375617707   05/01/2020          101.0              PPP
# 1  9677497701   05/01/2020          464.0              PPP
# 2  9547167709   05/01/2020          464.0              PPP
# 3  6448037706   05/01/2020          515.0              PPP
# 4  9609017706   05/01/2020          464.0              PPP
#
#                                      BorrowerName          BorrowerAddress  \
# 0                                   NOT AVAILABLE                      NaN
# 1          NORTH CHARLESTON HOSPITALITY GROUP LLC      192 College Park Rd
# 2                            Q AND J SERVICES LLC  301 Old Georgetown Road
# 3  OPTIMIZED PROCESS SOLUTIONS DBA AAA INDUSTRIES            24500 CAPITOL
# 4                            D2 POWER SPORTS, LLC           125 Simuel Dr.
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0          NaN           NaN         NaN            NaN  ...
# ...

# %%
data= pd.concat([data1, data2])
data.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020          464.0              PPP
# 1  9777677704   05/01/2020          464.0              PPP
# 2  5791407702   05/01/2020         1013.0              PPP
# 3  6223567700   05/01/2020          920.0              PPP
# 4  9662437702   05/01/2020          101.0              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# ...

# %%
data2.shape
# Out:
# (900000, 53)

# %%
data.shape
# Out:
# (1870076, 53)

# %%
data.columns
# Out:
# Index(['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState',
#        'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
#        'DEBT_INTEREST_PROCEED', 'BusinessType', 'OriginatingLenderLocationID',
# ...

# %%
data.isnull().sum()
# Out:
# LoanNumber                           0
# DateApproved                         0
# SBAOfficeCode                       13
# ProcessingMethod                     0
# BorrowerName                         7
# BorrowerAddress                    143
# BorrowerCity                       142
# BorrowerState                      153
# BorrowerZip                        141
# LoanStatusDate                 1172943
# LoanStatus                           0
# Term                                 0
# SBAGuarantyPercentage                0
# InitialApprovalAmount                0
# CurrentApprovalAmount                0
# UndisbursedAmount                  992
# FranchiseName                  1820420
# ServicingLenderLocationID           13
# ServicingLenderName                 13
# ServicingLenderAddress              13
# ServicingLenderCity                 13
# ServicingLenderState                13
# ServicingLenderZip                  13
# RuralUrbanIndicator                  0
# ...

# %%
data['BorrowerState'].isnull().sum()
# Out:
# 153

# %%
data = data.dropna(subset=['BorrowerState'])

# %%
data.drop(['BorrowerAddress', 'LoanStatusDate', 'FranchiseName'], axis= 1)
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 13      5502308207   08/08/2020         1084.0              PPP
# 14      6110847106   04/14/2020         1084.0              PPP
# 15      4539098204   08/06/2020         1084.0              PPP
# 16      5120868804   04/17/2021         1084.0              PPP
# 17      6650277102   04/14/2020         1084.0              PPP
# ...            ...          ...            ...              ...
# 899995  5186168809   04/17/2021          914.0              PPP
# 899996  5186218800   04/17/2021          912.0              PPP
# 899997  5186337402   05/11/2020          914.0              PPP
# 899998  5186478710   04/02/2021          912.0              PPP
# 899999  5186488702   04/02/2021          914.0              PPP
#
#                                  BorrowerName    BorrowerCity BorrowerState  \
# 13              KAKIVIK ASSET MANAGEMENT, LLC       ANCHORAGE            AK
# ...

# %% [markdown]
# ### avg of a city

# %%
city = data[data['BorrowerCity']=='Los Angeles']
city['InitialApprovalAmount'].mean()
# Out:
# 125411.74064115444

# %% [markdown]
# ### Loan Amount grouped by  KPIs

# %%
# Loan group by Business type
b_type= data[data['BusinessType']=='Corporation']
b_type
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 15      4539098204   08/06/2020         1084.0              PPP
# 17      6650277102   04/14/2020         1084.0              PPP
# 20      3323817108   04/11/2020         1084.0              PPP
# 22      3569947101   04/11/2020         1084.0              PPP
# 23      7234997101   04/14/2020         1084.0              PPP
# ...            ...          ...            ...              ...
# 899784  5160427309   04/30/2020          920.0              PPP
# 899796  5161317705   05/01/2020          920.0              PPP
# 899848  5167548505   02/27/2021          914.0              PPP
# 899886  5173447107   04/13/2020          914.0              PPP
# 899931  5178018407   02/08/2021          914.0              PPS
#
#                               BorrowerName                    BorrowerAddress  \
# 15                     CORVUS AIRLINES INC  4700 Old International Airport Rd
# ...

# %%
data['Race'].unique()
# Out:
# array(['Unanswered', 'White', 'Black or African American', 'Asian',
#        'American Indian or Alaska Native',
#        'Native Hawaiian or Other Pacific Islander', 'Eskimo & Aleut',
#        'Multi Group', 'Puerto Rican'], dtype=object)

# %%
# Loan group by Race type
race= data[data['Race']=='Asian']
race
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 267     7524657004   04/07/2020         1084.0              PPP
# 311     5668498305   01/25/2021         1084.0              PPS
# 356     5473778306   01/25/2021         1084.0              PPS
# 371     1967178305   01/20/2021         1084.0              PPS
# 384     2178907207   04/15/2020         1084.0              PPP
# ...            ...          ...            ...              ...
# 899727  5151698804   04/17/2021          920.0              PPS
# 899814  5163888701   04/02/2021          914.0              PPP
# 899879  5172748609   03/20/2021          942.0              PPS
# 899945  5179338705   04/02/2021          931.0              PPS
# 899956  5181138703   04/02/2021          914.0              PPP
#
#                               BorrowerName              BorrowerAddress  \
# 267                     SAGAYA CORPORATION  2524 Blueberry Road Ste 106
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Unanswered', 'Male Owned', 'Female Owned'], dtype=object)

# %%
# Loan group by Gender type
gender= data[data['Gender']=='Female Owned']
gender
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 38      1712467104   04/10/2020         1084.0              PPP
# 48      4966677003   04/04/2020         1084.0              PPP
# 53      5357627107   04/13/2020         1084.0              PPP
# 58      4878527102   04/13/2020         1084.0              PPP
# 74      4103747310   04/29/2020         1084.0              PPP
# ...            ...          ...            ...              ...
# 899975  5184358803   04/17/2021          914.0              PPP
# 899976  5184498810   04/17/2021          914.0              PPP
# 899982  5185078303   01/25/2021          912.0              PPS
# 899998  5186478710   04/02/2021          912.0              PPP
# 899999  5186488702   04/02/2021          914.0              PPP
#
#                                              BorrowerName  \
# 38                             ENGINEERED SOLUTIONS GROUP
# 48                         ALCAN ELEC. & ENGINEERING INC.
# ...

# %% [markdown]
# ### JobsReported VS InitialApprovalAmount

# %%
JobsReported= data['JobsReported']
InitialApprovalAmount= data['InitialApprovalAmount']

# %%
# co-relation
correlation = JobsReported.corr(InitialApprovalAmount)
print(correlation)
# Out:
# 0.7879562170254869

# %%
# visualization
data.groupby('JobsReported')['InitialApprovalAmount'].nunique().plot(kind='bar', figsize=(15, 10))
plt.show()

# %%
ServicingLenderName= data.loc[:, ['ServicingLenderName', 'InitialApprovalAmount']]
ServicingLenderName
# Out:
#                                     ServicingLenderName  InitialApprovalAmount
# 13                                        Northrim Bank             9571397.00
# 14      National Cooperative Bank, National Association             7666768.00
# 15                                     Idaho First Bank             7398947.89
# 16                           First National Bank Alaska             7223025.00
# 17                           First National Bank Alaska             6528631.40
# ...                                                 ...                    ...
# 899995                                 Benworth Capital               20833.00
# 899996              Harvest Small Business Finance, LLC               20833.00
# 899997                                   Customers Bank               20833.00
# 899998                     Amur Equipment Finance, Inc.               20833.00
# 899999              Harvest Small Business Finance, LLC               20833.00
#
# ...

# %% [markdown]
# ### City wise distribution of businesses granted loans

# %%
datanew= data[['BorrowerCity','InitialApprovalAmount']]
datanew
# Out:
#           BorrowerCity  InitialApprovalAmount
# 13           ANCHORAGE             9571397.00
# 14              BARROW             7666768.00
# 15           Anchorage             7398947.89
# 16           Anchorage             7223025.00
# 17               HOMER             6528631.40
# ...                ...                    ...
# 899995     Los Angeles               20833.00
# 899996        San Jose               20833.00
# 899997  Woodland Hills               20833.00
# 899998       Los Gatos               20833.00
# 899999     Simi Valley               20833.00
#
# [1869923 rows x 2 columns]

# %%
datanew.groupby(['BorrowerCity']).sum()
# Out:
#                                      InitialApprovalAmount
# BorrowerCity
# (North Hollywood Area), Los Angeles               81172.00
# , Albany                                         201100.00
# , Brooklyn                                       444900.00
# 02155                                            943400.00
# 100 Barranca Street                               20833.00
# ...                                                    ...
# yuba city                                        362920.00
# yucaipa                                           31720.00
# yucca valley                                      94124.00
# yuma                                             742548.93
# zionsville                                       495952.00
#
# [33170 rows x 1 columns]

# %% [markdown]
# ### Number of jobs reported by different business types

# %%
jobs_business= data[['JobsReported', 'BusinessType']]
jobs_business
# Out:
#         JobsReported                     BusinessType
# 13             385.0  Limited  Liability Company(LLC)
# 14             295.0          Non-Profit Organization
# 15             500.0                      Corporation
# 16             500.0             501(c)3 – Non Profit
# 17             439.0                      Corporation
# ...              ...                              ...
# 899995           1.0        Self-Employed Individuals
# 899996           1.0              Sole Proprietorship
# 899997           1.0  Limited  Liability Company(LLC)
# 899998           1.0              Sole Proprietorship
# 899999           1.0              Sole Proprietorship
#
# [1869923 rows x 2 columns]

# %% [markdown]
# ### Avg loan per business

# %%
loan_by_business_type= data[['BusinessType', 'InitialApprovalAmount']]
loan_by_business_type.groupby(['BusinessType']).mean()
# Out:
#                                      InitialApprovalAmount
# BusinessType
# 501(c) – Non Profit except 3,4,6,             2.676250e+05
# 501(c)19 – Non Profit Veterans                7.160800e+04
# 501(c)3 – Non Profit                          1.010489e+06
# 501(c)6 – Non Profit Membership               3.316047e+05
# Cooperative                                   4.792816e+05
# Corporation                                   3.404046e+05
# Employee Stock Ownership Plan(ESOP)           1.362882e+06
# Housing Co-op                                 3.576335e+05
# Independent Contractors                       1.452289e+04
# Joint Venture                                 3.835298e+05
# Limited  Liability Company(LLC)               3.228378e+05
# Limited Liability Partnership                 3.895565e+05
# Non-Profit Childcare Center                   3.905534e+05
# Non-Profit Organization                       5.435081e+05
# Partnership                                   3.523239e+05
# ...

# %% [markdown]
# ### loan amounts of Male Owned businesses VS FemaleOwned businesses

# %%
gender_loan= data[['Gender', 'BusinessType', 'InitialApprovalAmount']]
Unanswered = gender_loan[ gender_loan['Gender'] == 'Unanswered' ].index
gender_loan.drop(Unanswered, inplace = True)
gender_loan
# Out:
# C:\Users\Abdullah\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#               Gender                     BusinessType  InitialApprovalAmount
# 20        Male Owned                      Corporation              3009400.0
# 30        Male Owned                      Corporation              4780025.0
# 32        Male Owned         Subchapter S Corporation              4277000.0
# 36        Male Owned                      Corporation              3776300.0
# 38      Female Owned         Subchapter S Corporation              3894547.0
# ...              ...                              ...                    ...
# 899971    Male Owned  Limited  Liability Company(LLC)                20833.0
# ...

# %%
gender_loan.groupby(['Gender', 'BusinessType']).first()
# Out:
#                                                   InitialApprovalAmount
# Gender       BusinessType
# Female Owned 501(c) – Non Profit except 3,4,6,                 68258.00
#              501(c)19 – Non Profit Veterans                    20325.00
#              501(c)3 – Non Profit                            9245858.00
#              501(c)6 – Non Profit Membership                  167000.00
#              Cooperative                                      795700.00
#              Corporation                                     2987200.00
#              Employee Stock Ownership Plan(ESOP)             1254510.12
#              Housing Co-op                                    235371.00
#              Independent Contractors                          224500.00
#              Joint Venture                                    228600.00
#              Limited  Liability Company(LLC)                  942263.00
#              Limited Liability Partnership                    674000.00
# ...
